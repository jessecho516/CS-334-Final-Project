# %%
import numpy as np
import pandas as pd

# %%
business_df = pd.read_csv("sample_business.csv")
checkin_df = pd.read_csv("sample_checkin.csv")
review_df = pd.read_csv("sample_review.csv")
tip_df = pd.read_csv("sample_tip.csv")
user_df = pd.read_csv("sample_user.csv")

# %%
business_df
# Out:
#        Unnamed: 0             business_id                      name  \
# 0          124396  JlLh80kYzjVPcINyAezPKQ  Santa Cruz Animal Clinic
# 1          120435  2NOCur2ahFs3ypwT3VPNQQ             Lion's Choice
# 2           97721  6neDipsScU1gtNXKHb37ZQ                  Old Navy
# 3          125306  Q5PYc597t-2Usp905WpDWg            Mark Berg, DDS
# 4          149336  AtPTHg-NaRK93kFLEBDyOA      TheraTub Walk-In Tub
# ...           ...                     ...                       ...
# 39995      132126  8D10wCHiMvF8qfl8N-jE_A  Ardmore Grooming station
# 39996       54777  9BRogQ1ZU-agQCPG-a4zIg                     Groom
# 39997       46352  o_9hBDxSVk0urSG9DhSF8A            Airport Motors
# 39998       55404  Z0U0sPwogMRdbhNZzx2wgw           The Boiling Pot
# 39999         213  ZU6NodDOWaabGkeNpOWdXw           530 Pub & Grill
#
#                   address              city state postal_code   latitude  \
# 0      431 W Robertson St           Brandon    FL       33511  27.935510
# 1      9621 Manchester Rd         St. Louis    MO       63119  38.609162
# 2        2440 Chemical Rd  Plymouth Meeting    PA       19462  40.106164
# 3                     NaN       Saint Louis    MO       63141  38.662494
# 4                     NaN           Brandon    FL       33511  27.908259
# ...                   ...               ...   ...         ...        ...
# 39995      7 Anderson Ave           Ardmore    PA       19003  40.008321
# 39996      1324 Locust St      Philadelphia    PA       19107  39.948062
# 39997       5950 Olney St            Goleta    CA       93117  34.429898
# 39998       319 Market St      Philadelphia    PA       19106  39.950390
# 39999    530 Cleveland St        Clearwater    FL       33755  27.965747
#
#         longitude  stars  review_count  is_open  \
# 0      -82.291042    3.5            23        1
# 1      -90.366873    4.0            13        1
# 2      -75.292746    3.5             8        1
# 3      -90.478549    3.0            18        1
# 4      -82.290915    3.5             5        1
# ...           ...    ...           ...      ...
# 39995  -75.290824    3.5            18        1
# 39996  -75.163653    4.5           172        1
# 39997 -119.829963    4.0            63        1
# 39998  -75.146338    3.5            40        0
# 39999  -82.798901    4.5             6        1
#
#                                               attributes  \
# 0                                                    NaN
# 1      {'RestaurantsAttire': "'casual'", 'Restaurants...
# 2      {'BikeParking': 'False', 'BusinessParking': "{...
# 3                          {'ByAppointmentOnly': 'True'}
# 4      {'RestaurantsPriceRange2': '2', 'BikeParking':...
# ...                                                  ...
# 39995                                                NaN
# 39996  {'ByAppointmentOnly': 'True', 'BusinessAccepts...
# 39997             {'BusinessAcceptsCreditCards': 'True'}
# 39998  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 39999  {'WheelchairAccessible': 'True', 'RestaurantsT...
#
#                                               categories  \
# 0                      Pets, Pet Services, Veterinarians
# 1      Fast Food, Restaurants, American (Traditional)...
# 2      Fashion, Women's Clothing, Men's Clothing, Chi...
# 3      Oral Surgeons, Dentists, Health & Medical, End...
# 4      Shopping, Kitchen & Bath, Home Services, Home ...
# ...                                                  ...
# 39995                   Pet Services, Pet Groomers, Pets
# 39996                Hair Salons, Barbers, Beauty & Spas
# 39997                            Auto Repair, Automotive
# 39998   Seafood, Asian Fusion, Restaurants, Cajun/Creole
# 39999  American (Traditional), Restaurants, Burgers, ...
#
#                                                    hours
# 0      {'Monday': '7:30-17:30', 'Tuesday': '7:30-17:3...
# 1      {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...
# 2      {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 3                                                    NaN
# 4      {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...
# ...                                                  ...
# 39995                                                NaN
# 39996  {'Monday': '9:0-18:0', 'Tuesday': '9:0-18:0', ...
# 39997  {'Monday': '7:30-17:0', 'Tuesday': '7:30-17:0'...
# 39998  {'Monday': '14:0-20:0', 'Tuesday': '14:0-20:0'...
# 39999  {'Tuesday': '11:0-23:0', 'Wednesday': '11:0-23...
#
# [40000 rows x 15 columns]
