# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

color = sns.color_palette()
sns.set_style("dark")
warnings.filterwarnings("ignore")

# %%
# importing datasets
restaurant = pd.read_csv('sample_restaurant.csv')
restaurant
# Out:
#        Unnamed: 0             business_id                            name  \
# 0          126141  9XotjNYdPzWCokrVMRo4Mg        The Great Canadian Bagel
# 1            8518  Y92Nc9GhuXWvIABqNtSWGA                       Tavern 52
# 2           11669  b5byt9ewnM1U57ygWTTV2g           Crab Du Jour - Delran
# 3          116916  4jICs7no7322VjY4hqHVAg              La Cocinita Cubana
# 4           66207  pWDE_rueENu_f5HKA_AsWw   Dune Coffee Roasters - Storke
# ...           ...                     ...                             ...
# 39995      141107  guwb1zuNEMtJVproo0ntFw                         La Boca
# 39996       66695  -78Va3llKcPbL6SW4is8lw          Mungo's Italian Eatery
# 39997      101198  2pj5byDMoMDu-d0bTu2Sew                             Pip
# 39998      124342  RKRy17pwMJAbehSkZglwjw                       Jia's Wok
# 39999       38524  s8TE6aXrwEQmODAmYlguUA  Riliberto's Fresh Mexican Food
#
#                       address           city state postal_code   latitude  \
# 0      120 Wye Road, Unit 101  Sherwood Park    AB     T8A 6P2  53.512479
# 1            329 Kennett Pike     Mendenhall    PA       19357  39.853403
# 2                 4000 US-130         Delran    NJ       08075  40.011577
# 3              113 Central Dr        Brandon    FL       33510  27.939235
# 4             250 A Storke Rd         Goleta    CA       93117  34.429540
# ...                       ...            ...   ...         ...        ...
# 39995    870 Tchoupitoulas St    New Orleans    LA       70130  29.943455
# 39996        100 East Main St   Collinsville    IL       62234  38.669906
# 39997         10403 83 Ave NW       Edmonton    AB     T6E 2C7  53.518958
# 39998          477 E Plumb Ln           Reno    NV       89502  39.506363
# 39999        3344 N Oracle Rd         Tucson    AZ       85705  32.267304
#
#         longitude  stars  review_count  is_open  \
# 0     -113.327738    4.0             9        1
# 1      -75.640789    3.5            21        1
# 2      -74.961777    3.0            25        1
# 3      -82.292208    4.5            33        1
# 4     -119.869271    4.0           159        1
# ...           ...    ...           ...      ...
# 39995  -90.067341    4.0           420        1
# 39996  -89.985827    4.0           124        1
# 39997 -113.497891    4.0           117        1
# 39998 -119.797213    3.0            35        1
# 39999 -110.977651    2.5             6        1
#
#                                               attributes  \
# 0      {'BikeParking': 'True', 'OutdoorSeating': 'Fal...
# 1      {'RestaurantsReservations': 'True', 'WiFi': "u...
# 2      {'Alcohol': "u'full_bar'", 'Caters': 'True', '...
# 3      {'BusinessAcceptsCreditCards': 'True', 'GoodFo...
# 4      {'NoiseLevel': "u'average'", 'Alcohol': "'none...
# ...                                                  ...
# 39995  {'RestaurantsReservations': 'True', 'WiFi': "u...
# 39996  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
# 39997  {'GoodForMeal': "{'dessert': False, 'latenight...
# 39998  {'Alcohol': "u'none'", 'RestaurantsGoodForGrou...
# 39999  {'RestaurantsDelivery': 'None', 'RestaurantsTa...
#
#                                               categories  \
# 0      Breakfast & Brunch, Sandwiches, Bagels, Coffee...
# 1      Breakfast & Brunch, Restaurants, American (Tra...
# 2      Live/Raw Food, Cajun/Creole, Seafood, Restaurants
# 3                            Spanish, Cuban, Restaurants
# 4      Food, Restaurants, Cafes, Coffee Roasteries, C...
# ...                                                  ...
# 39995  Argentine, Latin American, Steakhouses, Desser...
# 39996  Seafood, Steakhouses, Italian, Salad, Restaurants
# 39997  Comfort Food, Food, Wine Bars, Breakfast & Bru...
# 39998                               Chinese, Restaurants
# 39999    Mexican, Restaurants, Breakfast & Brunch, Salad
#
#                                                    hours
# 0      {'Monday': '7:0-17:0', 'Tuesday': '7:0-17:0', ...
# 1      {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...
# 2      {'Monday': '11:30-22:0', 'Tuesday': '11:30-22:...
# 3      {'Monday': '7:0-15:30', 'Tuesday': '7:0-15:30'...
# 4      {'Monday': '6:30-16:0', 'Tuesday': '6:30-16:0'...
# ...                                                  ...
# 39995  {'Tuesday': '17:30-22:0', 'Wednesday': '17:30-...
# 39996  {'Monday': '16:0-21:0', 'Tuesday': '16:0-21:0'...
# 39997  {'Monday': '9:0-23:0', 'Tuesday': '9:0-23:0', ...
# 39998  {'Monday': '10:0-21:0', 'Tuesday': '10:0-21:0'...
# 39999  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
#
# [40000 rows x 15 columns]

# %%
# rating distribution
stars = restaurant['stars'].value_counts()
stars = stars.sort_index()

# plot
plt.figure(figsize=(8,4))
ax = sns.barplot(stars.index, stars.values, alpha=0.8)
plt.title("Star Rating Distribution")
plt.ylabel("# of businesses", fontsize=12)
plt.xlabel('Star Ratings', fontsize=12)
ax.bar_label(ax.containers[0], label_type='edge')
# Out:
# [Text(0, 0, '185'),
#  Text(0, 0, '1119'),
#  Text(0, 0, '2249'),
#  Text(0, 0, '3705'),
#  Text(0, 0, '5879'),
#  Text(0, 0, '9005'),
#  Text(0, 0, '10323'),
#  Text(0, 0, '6363'),
#  Text(0, 0, '1172')]
